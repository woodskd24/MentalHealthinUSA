# %% [markdown]
# <a href="https://colab.research.google.com/github/woodskd24/MentalHealthinUSA/blob/main/Bipolar_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Data From https://data.world/vizzup/mental-health-depression-disorder-data/workspace/file?filename=Mental+health+Depression+disorder+Data.xlsx
import pandas as pd
from sklearn.model_selection import train_test_split
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/MHPred.csv')
df
# Out:
#     Year  Schizophrenia (%)  Bipolar disorder (%)  Eating disorders (%)  \
# 0   1990           0.340897              0.653706              0.468676
# 1   1991           0.338913              0.653953              0.473575
# 2   1992           0.337343              0.654205              0.478610
# 3   1993           0.336207              0.654431              0.483539
# 4   1994           0.335536              0.654620              0.488235
# 5   1995           0.335363              0.654721              0.492368
# 6   1996           0.335806              0.654749              0.496752
# 7   1997           0.336797              0.654720              0.501560
# 8   1998           0.338085              0.654658              0.506483
# 9   1999           0.339410              0.654564              0.511072
# 10  2000           0.340512              0.654443              0.514863
# 11  2001           0.341186              0.654371              0.518306
# 12  2002           0.341483              0.654349              0.522170
# 13  2003           0.341535              0.654343              0.526130
# 14  2004           0.341472              0.654313              0.529332
# 15  2005           0.341427              0.654228              0.531157
# 16  2006           0.341031              0.654080              0.532178
# 17  2007           0.340069              0.653896              0.533067
# 18  2008           0.338901              0.653691              0.533768
# 19  2009           0.337887              0.653468              0.534175
# 20  2010           0.337390              0.653247              0.534076
# 21  2011           0.337190              0.653008              0.533199
# 22  2012           0.336852              0.652748              0.531514
# 23  2013           0.336404              0.652479              0.528946
# 24  2014           0.335860              0.652195              0.525990
# 25  2015           0.335243              0.651890              0.522109
# 26  2016           0.334578              0.651569              0.517728
# 27  2017           0.333890              0.651236              0.512844
#
#     Anxiety disorders (%)  Drug use disorders (%)  Depression (%)  \
# 0                6.576884                2.367794        4.677591
# 1                6.553351                2.345466        4.660871
# 2                6.536143                2.339515        4.651949
# 3                6.525536                2.347095        4.648701
# 4                6.522278                2.365738        4.649294
# 5                6.526489                2.392582        4.650869
# 6                6.578023                2.456048        4.662902
# 7                6.688847                2.564591        4.689154
# 8                6.818473                2.688823        4.720716
# 9                6.926351                2.800595        4.749991
# 10               6.971563                2.869426        4.766992
# 11               6.971995                2.905605        4.774031
# 12               6.971891                2.936109        4.778244
# 13               6.970935                2.962640        4.781680
# 14               6.968875                2.983414        4.785232
# 15               6.965249                2.998771        4.791258
# 16               6.937038                3.000826        4.793213
# 17               6.875454                2.989141        4.786623
# 18               6.801899                2.974336        4.776402
# 19               6.737790                2.966808        4.765950
# 20               6.704455                2.977144        4.761551
# 21               6.693384                3.007049        4.762322
# 22               6.682107                3.052340        4.765481
# 23               6.671047                3.110712        4.772422
# 24               6.660473                3.181115        4.782222
# 25               6.650662                3.262674        4.795954
# 26               6.642099                3.353142        4.813114
# 27               6.635055                3.452476        4.835610
#
#     Alcohol use disorders (%)
# 0                    2.173751
# 1                    2.139292
# 2                    2.107931
# 3                    2.080669
# 4                    2.058632
# 5                    2.042931
# 6                    2.033987
# 7                    2.030590
# 8                    2.031176
# 9                    2.034175
# 10                   2.038026
# 11                   2.043577
# 12                   2.051480
# 13                   2.059815
# 14                   2.066706
# 15                   2.070251
# 16                   2.063498
# 17                   2.045624
# 18                   2.023935
# 19                   2.005749
# 20                   1.998437
# 21                   1.999569
# 22                   2.001951
# 23                   2.005814
# 24                   2.011345
# 25                   2.018738
# 26                   2.028263
# 27                   2.040087

# %%
X = df[['Year']]
y = df['Bipolar disorder (%)']

# %%
sns.scatterplot(x = "Year", y = "Bipolar disorder (%)", data = df)

# %% [markdown]
# #Weka

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
import xgboost as xgb
from scipy.stats import uniform, randint

# %%
xgb = xgb.XGBRegressor(objective="reg:linear", random_state=42)

x1 = xgb.fit(X_train, y_train, eval_set=[(X_test, y_test)])

y_pred1 = x1.predict(X_test)
# Out:
# [16:45:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:0.138919
# [1]	validation_0-rmse:0.125697
# [2]	validation_0-rmse:0.11373
# [3]	validation_0-rmse:0.102901
# [4]	validation_0-rmse:0.0931
# [5]	validation_0-rmse:0.084231
# [6]	validation_0-rmse:0.076204
# [7]	validation_0-rmse:0.06894
# [8]	validation_0-rmse:0.062366
# [9]	validation_0-rmse:0.056416
# [10]	validation_0-rmse:0.051032
# [11]	validation_0-rmse:0.04616
# [12]	validation_0-rmse:0.04175
# [13]	validation_0-rmse:0.03776
# [14]	validation_0-rmse:0.034149
# [15]	validation_0-rmse:0.030881
# [16]	validation_0-rmse:0.027923
# [17]	validation_0-rmse:0.025247
# [18]	validation_0-rmse:0.022825
# [19]	validation_0-rmse:0.020634
# [20]	validation_0-rmse:0.018651
# [21]	validation_0-rmse:0.016857
# [22]	validation_0-rmse:0.015233
# [23]	validation_0-rmse:0.013764
# [24]	validation_0-rmse:0.012435
# [25]	validation_0-rmse:0.011233
# [26]	validation_0-rmse:0.010145
# [27]	validation_0-rmse:0.009162
# [28]	validation_0-rmse:0.008272
# [29]	validation_0-rmse:0.007468
# [30]	validation_0-rmse:0.006741
# [31]	validation_0-rmse:0.006083
# [32]	validation_0-rmse:0.00549
# [33]	validation_0-rmse:0.004946
# [34]	validation_0-rmse:0.004493
# [35]	validation_0-rmse:0.004083
# [36]	validation_0-rmse:0.003678
# [37]	validation_0-rmse:0.003313
# [38]	validation_0-rmse:0.003009
# [39]	validation_0-rmse:0.002735
# [40]	validation_0-rmse:0.002451
# [41]	validation_0-rmse:0.002227
# [42]	validation_0-rmse:0.002005
# [43]	validation_0-rmse:0.001823
# [44]	validation_0-rmse:0.001642
# [45]	validation_0-rmse:0.001514
# [46]	validation_0-rmse:0.001398
# [47]	validation_0-rmse:0.001263
# [48]	validation_0-rmse:0.001157
# [49]	validation_0-rmse:0.001048
# [50]	validation_0-rmse:0.000973
# [51]	validation_0-rmse:0.000885
# [52]	validation_0-rmse:0.000806
# [53]	validation_0-rmse:0.000754
# [54]	validation_0-rmse:0.000691
# [55]	validation_0-rmse:0.000634
# [56]	validation_0-rmse:0.000584
# [57]	validation_0-rmse:0.000541
# [58]	validation_0-rmse:0.000502
# [59]	validation_0-rmse:0.000469
# [60]	validation_0-rmse:0.000447
# [61]	validation_0-rmse:0.000421
# [62]	validation_0-rmse:0.000398
# [63]	validation_0-rmse:0.000379
# [64]	validation_0-rmse:0.000363
# [65]	validation_0-rmse:0.000349
# [66]	validation_0-rmse:0.000337
# [67]	validation_0-rmse:0.000328
# [68]	validation_0-rmse:0.00032
# [69]	validation_0-rmse:0.000313
# [70]	validation_0-rmse:0.000308
# [71]	validation_0-rmse:0.000304
# [72]	validation_0-rmse:0.0003
# [73]	validation_0-rmse:0.000297
# [74]	validation_0-rmse:0.000295
# [75]	validation_0-rmse:0.000293
# [76]	validation_0-rmse:0.000292
# [77]	validation_0-rmse:0.00029
# [78]	validation_0-rmse:0.00029
# [79]	validation_0-rmse:0.000289
# [80]	validation_0-rmse:0.000288
# [81]	validation_0-rmse:0.000288
# [82]	validation_0-rmse:0.000288
# [83]	validation_0-rmse:0.000288
# [84]	validation_0-rmse:0.000287
# [85]	validation_0-rmse:0.000287
# [86]	validation_0-rmse:0.000287
# [87]	validation_0-rmse:0.000287
# [88]	validation_0-rmse:0.000287
# [89]	validation_0-rmse:0.000287
# [90]	validation_0-rmse:0.000287
# [91]	validation_0-rmse:0.000287
# [92]	validation_0-rmse:0.000287
# [93]	validation_0-rmse:0.000287
# [94]	validation_0-rmse:0.000288
# [95]	validation_0-rmse:0.000288
# [96]	validation_0-rmse:0.000288
# [97]	validation_0-rmse:0.000288
# [98]	validation_0-rmse:0.000288
# [99]	validation_0-rmse:0.000288

# %%
from sklearn import metrics
meanAbErr = metrics.mean_absolute_error(y_test, y_pred1)
meanSqErr = metrics.mean_squared_error(y_test, y_pred1)
rootMeanSqErr = np.sqrt(metrics.mean_squared_error(y_test, y_pred1))
print('R squared: {:.2f}'.format(x1.score(X_train,y_train)*100))
print('Mean Absolute Error:', meanAbErr)
print('Mean Square Error:', meanSqErr)
print('Root Mean Square Error:', rootMeanSqErr)
# Out:
# R squared: 89.41
# Mean Absolute Error: 0.00021379141483221818
# Mean Square Error: 8.281282925606814e-08
# Root Mean Square Error: 0.00028777218290875183

# %%
print("Prediction for test set: {}".format(y_pred1))
# Out:
# Prediction for test set: [0.6521541 0.6538759 0.6538759 0.6538759 0.65424   0.65424   0.6526975
#  0.65424   0.6526975]

# %%
xG_diff = pd.DataFrame({'Actual value': y_test, 'Predicted value': y_pred1})
xG_diff.head()
# Out:
#     Actual value  Predicted value
# 24      0.652195         0.652154
# 17      0.653896         0.653876
# 19      0.653468         0.653876
# 20      0.653247         0.653876
# 14      0.654313         0.654240

# %%
plt.scatter(X_test,y_test)
plt.plot(X_test, y_pred1, 'Red')
plt.show()
