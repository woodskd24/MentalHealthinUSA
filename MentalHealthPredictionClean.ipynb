# %% [markdown]
# <a href="https://colab.research.google.com/github/woodskd24/MentalHealthinUSA/blob/main/MentalHealthPredictionClean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Data From https://data.world/vizzup/mental-health-depression-disorder-data/workspace/file?filename=Mental+health+Depression+disorder+Data.xlsx
import pandas as pd
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
MH = pd.read_csv('/content/drive/MyDrive/MentalHealthData.csv')
MH
# Out:
#            Entity Code  Year  Schizophrenia (%)  Bipolar disorder (%)  \
# 0     Afghanistan  AFG  1990           0.160560              0.697779
# 1     Afghanistan  AFG  1991           0.160312              0.697961
# 2     Afghanistan  AFG  1992           0.160135              0.698107
# 3     Afghanistan  AFG  1993           0.160037              0.698257
# 4     Afghanistan  AFG  1994           0.160022              0.698469
# ...           ...  ...   ...                ...                   ...
# 6463     Zimbabwe  ZWE  2013           0.155670              0.607993
# 6464     Zimbabwe  ZWE  2014           0.155993              0.608610
# 6465     Zimbabwe  ZWE  2015           0.156465              0.609363
# 6466     Zimbabwe  ZWE  2016           0.157111              0.610234
# 6467     Zimbabwe  ZWE  2017           0.157963              0.611242
#
#       Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# ...

# %%
USM = MH[MH['Entity'] == "United States"]
USM
# Out:
#              Entity Code  Year  Schizophrenia (%)  Bipolar disorder (%)  \
# 6076  United States  USA  1990           0.340897              0.653706
# 6077  United States  USA  1991           0.338913              0.653953
# 6078  United States  USA  1992           0.337343              0.654205
# 6079  United States  USA  1993           0.336207              0.654431
# 6080  United States  USA  1994           0.335536              0.654620
# 6081  United States  USA  1995           0.335363              0.654721
# 6082  United States  USA  1996           0.335806              0.654749
# 6083  United States  USA  1997           0.336797              0.654720
# 6084  United States  USA  1998           0.338085              0.654658
# 6085  United States  USA  1999           0.339410              0.654564
# 6086  United States  USA  2000           0.340512              0.654443
# 6087  United States  USA  2001           0.341186              0.654371
# ...

# %%
USM.describe()
# Out:
#               Year  Schizophrenia (%)  Bipolar disorder (%)  \
# count    28.000000          28.000000             28.000000
# mean   2003.500000           0.338117              0.653710
# std       8.225975           0.002424              0.001028
# min    1990.000000           0.333890              0.651236
# 25%    1996.750000           0.336120              0.653187
# 50%    2003.500000           0.337639              0.654143
# 75%    2010.250000           0.340608              0.654434
# max    2017.000000           0.341535              0.654749
#
#        Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# count             28.000000              28.000000               28.000000
# mean               0.513658               6.741584                2.844713
# std                0.020454               0.165191                0.327117
# min                0.468676               6.522278                2.339515
# ...

# %%
USM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28 entries, 6076 to 6103
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Entity                     28 non-null     object
#  1   Code                       28 non-null     object
#  2   Year                       28 non-null     int64
#  3   Schizophrenia (%)          28 non-null     float64
#  4   Bipolar disorder (%)       28 non-null     float64
#  5   Eating disorders (%)       28 non-null     float64
#  6   Anxiety disorders (%)      28 non-null     float64
#  7   Drug use disorders (%)     28 non-null     float64
#  8   Depression (%)             28 non-null     float64
#  9   Alcohol use disorders (%)  28 non-null     float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 2.4+ KB

# %%
USA = USM.drop(columns = "Code")
df = USA.drop(columns = "Entity")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28 entries, 6076 to 6103
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year                       28 non-null     int64
#  1   Schizophrenia (%)          28 non-null     float64
#  2   Bipolar disorder (%)       28 non-null     float64
#  3   Eating disorders (%)       28 non-null     float64
#  4   Anxiety disorders (%)      28 non-null     float64
#  5   Drug use disorders (%)     28 non-null     float64
#  6   Depression (%)             28 non-null     float64
#  7   Alcohol use disorders (%)  28 non-null     float64
# dtypes: float64(7), int64(1)
# memory usage: 2.0 KB

# %%
df.isnull().sum()
# Out:
# Year                         0
# Schizophrenia (%)            0
# Bipolar disorder (%)         0
# Eating disorders (%)         0
# Anxiety disorders (%)        0
# Drug use disorders (%)       0
# Depression (%)               0
# Alcohol use disorders (%)    0
# dtype: int64

# %%
df.shape
# Out:
# (28, 8)

# %%
df.to_csv(r'/content/drive/MyDrive/MHPred.csv', index = False)
